// %% [markdown]
// easy conversion between java and scala map
//
// can choose between mutable and immutable map (Default)
//
// can choose between HashMap (default) or TreeMap

// %%
val scores = Map("Alice" -> 3, "Bob" -> 10, "Cindy" -> 8)
// Out:
// scores: Map[String, Int] = Map("Alice" -> 3, "Bob" -> 10, "Cindy" -> 8)

// %%
val scores = scala.collection.mutable.Map("Alice" -> 10, "Bob" -> 3, "Cindy" -> 8)
// Out:
// scores: collection.mutable.Map[String, Int] = Map("Bob" -> 3, "Alice" -> 10, "Cindy" -> 8)

// %% [markdown]
// can use either `"Alice" -> 10` or `("Alice", 10)` to define a map

// %%
val scores = Map(("Alice", 10), ("Bob", 3), ("Cindy", 8))
// Out:
// scores: Map[String, Int] = Map("Alice" -> 10, "Bob" -> 3, "Cindy" -> 8)

// %%
println(scores("Alice"))
// Out:
// 10

// %%
scores.getOrElse("Bob", 0)
// Out:
// res4: Int = 3

// %%
scores.get("NotExist")
// Out:
// res5: Option[Int] = None

// %%
source("NotExist")
// Out:
// cmd6.sc:1: not found: value source
// val res6 = source("NotExist")
//            ^
// Compilation Failed

// %%
scores.get("Alice")
// Out:
// res6: Option[Int] = Some(10)

// %%
val scores2 = scores.withDefault(_.length)
// Out:
// scores2: collection.mutable.Map[String, Int] = Map()

// %%
val zeldasScore2 = scores2.get("Zelda")
// Out:
// zeldasScore2: Option[Int] = None

// %% [raw]
// iterating maps

// %%
for ((k, v) <- Map("Alice" -> 3, "Bob" -> 10, "Cindy" -> 8))
println (k, v)
// Out:
// (Alice,3)
// (Bob,10)
// (Cindy,8)

// %%
Map("Alice" -> 3, "Bob" -> 10, "Cindy" -> 8).keySet
// Out:
// res14: Set[String] = Set("Alice", "Bob", "Cindy")

// %%
Map("Alice" -> 3, "Bob" -> 10, "Cindy" -> 8).values
// Out:
// res15: Iterable[Int] = MapLike(3, 10, 8)
